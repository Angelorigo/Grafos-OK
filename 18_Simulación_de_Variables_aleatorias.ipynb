# %% [markdown]
# <a href="https://colab.research.google.com/github/Angelorigo/Grafos-OK/blob/main/18_Simulaci%C3%B3n_de_Variables_aleatorias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**ÁLVAREZ SERVÍN ÁNGEL RODRIGO**
#
# ##- MATEMÁTICA ALGORÍTMICA.
# ##- MODELOS ESTOCÁSTICOS.
# ##- ESFM IPN, MAYO 2026.
#
# Este programa contiene todos los códigos para realizar las simulaciones para generar variables aleatorias de las distribuciones dentro de la Actividad 4, las cuales son:
# - Weibull
# - Uniforme
# - Cauchy
# - Logistica
# - Pareto
